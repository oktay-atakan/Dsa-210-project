# %%
import requests
import pandas as pd

def get_rawg_data(api_key, pages=5):
    games = []
    for page in range(1, pages + 1):
        url = f"https://api.rawg.io/api/games?key={api_key}&dates=2015-01-01,2024-12-31&page={page}"
        resp = requests.get(url).json()

        for g in resp["results"]:
            games.append({
                "id": g["id"],
                "name": g["name"],
                "released": g["released"],
                "metacritic": g.get("metacritic"),
                "rating": g["rating"],
                "ratings_count": g["ratings_count"],
                "genres": ", ".join([x["name"] for x in g["genres"]])
            })
    return pd.DataFrame(games)

# %%
import os
os.makedirs("data", exist_ok=True)

API_KEY = "5f00c6d161394998a2bf2169b2101d6c"

df = get_rawg_data(API_KEY)
df.head()

df.to_csv("data/rawg_data.csv", index=False)
